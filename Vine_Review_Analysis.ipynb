# %%
# Import Dependencies
import pandas as pd

# %%
vine_df = pd.read_csv("vine_table.csv")
vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0        RSH1OZ87OYK92            2              2            3    N
# 1       R1WFOQ3N9BO65I            5              0            0    N
# 2        R3YOOS71KM5M9            5              0            0    N
# 3       R3R14UATT3OUFU            5              0            0    N
# 4        RV2W9SGDNQA2C            5              0            0    N
# ...                ...          ...            ...          ...  ...
# 145426  R2G7DI8NYXZB5R            4              2            3    N
# 145427  R3QRKP4DS759BP            1             13           16    N
# 145428  R24K4C0ZC3093U            3              3            3    N
# 145429  R13OA3TRCM8IBM            1             20           22    N
# 145430  R1PFDIHC9TM6V4            4              4            4    N
#
#        verified_purchase
# 0                      N
# 1                      Y
# 2                      Y
# 3                      Y
# ...

# %%
vine_filtered = vine_df.loc[vine_df["total_votes"] >= 20, :]
vine_filtered.dtypes
# Out:
# review_id            object
# star_rating           int64
# helpful_votes         int64
# total_votes           int64
# vine                 object
# verified_purchase    object
# dtype: object

# %%
vine_helpful = vine_filtered.loc[lambda vine_filtered: (vine_filtered["helpful_votes"]) / (vine_filtered["total_votes"]) >=0.5]
vine_helpful
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 278      RV4UH0OWW97K4            5             19           22    N
# 859      RG6GT6G9WNYT1            5             22           22    N
# 924      RFBXE3Q3GYQYO            5             68           70    N
# 1662    R34S64NPUZOS90            5             23           24    N
# 1816    R35O3GV3HZUX8B            5             58           63    N
# ...                ...          ...            ...          ...  ...
# 145402  R2XZUU9DXCYWVS            5             87           97    N
# 145407  R1OJBA4VLHU9B3            4             51           51    N
# 145409  R2TDYPLG4M7XQV            3             28           31    N
# 145423  R3OZBHDT6V61RK            5             27           45    N
# 145429  R13OA3TRCM8IBM            1             20           22    N
#
#        verified_purchase
# 278                    N
# 859                    N
# 924                    Y
# 1662                   N
# ...

# %%
vine_helpful_paid = vine_helpful.loc[vine_helpful["vine"] == "Y",:]
vine_helpful_paid
# Out:
# Empty DataFrame
# Columns: [review_id, star_rating, helpful_votes, total_votes, vine, verified_purchase]
# Index: []

# %%
vine_helpful_unpaid = vine_helpful.loc[vine_helpful["vine"] == "N",:]
vine_helpful_unpaid
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 278      RV4UH0OWW97K4            5             19           22    N
# 859      RG6GT6G9WNYT1            5             22           22    N
# 924      RFBXE3Q3GYQYO            5             68           70    N
# 1662    R34S64NPUZOS90            5             23           24    N
# 1816    R35O3GV3HZUX8B            5             58           63    N
# ...                ...          ...            ...          ...  ...
# 145402  R2XZUU9DXCYWVS            5             87           97    N
# 145407  R1OJBA4VLHU9B3            4             51           51    N
# 145409  R2TDYPLG4M7XQV            3             28           31    N
# 145423  R3OZBHDT6V61RK            5             27           45    N
# 145429  R13OA3TRCM8IBM            1             20           22    N
#
#        verified_purchase
# 278                    N
# 859                    N
# 924                    Y
# 1662                   N
# ...

# %%
total_unpaid_reviews = vine_helpful_unpaid.count()
total_unpaid_reviews
# Out:
# review_id            1685
# star_rating          1685
# helpful_votes        1685
# total_votes          1685
# vine                 1685
# verified_purchase    1685
# dtype: int64

# %%
unpaid_5_star = vine_helpful_unpaid.loc[vine_helpful_unpaid["star_rating"] == 5,:].count()
unpaid_5_star
# Out:
# review_id            631
# star_rating          631
# helpful_votes        631
# total_votes          631
# vine                 631
# verified_purchase    631
# dtype: int64

# %%
percentage_5_star = (unpaid_5_star / total_unpaid_reviews) * 100
percentage_5_star
# Out:
# review_id            37.448071
# star_rating          37.448071
# helpful_votes        37.448071
# total_votes          37.448071
# vine                 37.448071
# verified_purchase    37.448071
# dtype: float64
